# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD, RMSprop, Adam, AdamW
from tensorflow.keras import regularizers, models, layers
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.preprocessing import StandardScaler

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import optuna
import wandb
import gc
import cv2

import os
import sqlite3
# Out:
# 2026-02-22 04:59:40.849953: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-02-22 04:59:40.849978: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-02-22 04:59:40.850812: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-02-22 04:59:40.855556: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
tf.keras.backend.clear_session()

gpus = tf.config.list_physical_devices('GPU')

if gpus:
    print("TensorFlow is using the GPU \n", gpus)
else:
    print("No GPU detected.")
# Out:
# TensorFlow is using the GPU
#  [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2026-02-22 04:59:49.392292: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-02-22 04:59:49.401730: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-02-22 04:59:49.404292: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355

# %%
import wandb 

from wandb.integration.keras import WandbMetricsLogger

wandb.require("core")
wandb.login()
# Out:
# wandb: WARNING `wandb.require('core')` is a no-op as it is now the default behavior.
# wandb: Currently logged in as: emmdaz (emmdaz-zzz) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
# We create the dataframe for all the data subsets for training, test and validation
sg = pd.read_csv("/tf/Higgs-Boson-LHC-Collision-Detector/Datasets/Signal.csv")
bg = pd.read_csv("/tf/Higgs-Boson-LHC-Collision-Detector/Datasets/Background.csv")

sg_sample1 = sg.sample(frac = 0.5, random_state = 4)
sg_sample2 = sg.sample(frac = 0.3, random_state = 4)
sg_sample3 = sg.sample(frac = 0.2, random_state = 4)

bg_sample1 = bg.sample(frac = 0.5, random_state = 4)
bg_sample2 = bg.sample(frac = 0.3, random_state = 4)
bg_sample3 = bg.sample(frac = 0.2, random_state = 4)

train = pd.concat([sg_sample1, bg_sample1])
train = train.drop(columns = ["Unnamed: 0"])
test = pd.concat([sg_sample2, bg_sample2])
test = test.drop(columns = ["Unnamed: 0"])
val = pd.concat([sg_sample3, bg_sample3])
val = val.drop(columns = ["Unnamed: 0"])

# Now we can create the subsets:
X_train, X_test, X_val = train.drop(columns = ["label"]), test.drop(columns = ["label"]), val.drop(columns = ["label"])
y_train, y_test, y_val = train["label"], test["label"], val["label"]

# And we stardardize the data:

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)

# Check the sizes
print("Train size:", len(X_train))
print("Validation size:", len(X_val))
print("Test size:", len(X_test))
# Out:
# Train size: 277081
# Validation size: 110832
# Test size: 166248

# %%
X_train[0].shape
# Out:
# (12,)

# %%
train.head()
# Out:
#         PRI_jet_leading_pt  PRI_jet_subleading_pt  PRI_jet_leading_eta  \
# 361401           95.568436              89.002968             1.060876
# 120470          115.015144             102.003731            -0.713616
# 376542          132.180600              77.472824            -0.249687
# 349195          131.677500             129.195847            -0.346833
# 48316           118.896320             116.049370             0.549450
#
#         PRI_jet_subleading_eta  PRI_jet_leading_phi  PRI_jet_subleading_phi  \
# 361401               -1.084730             2.732387               -0.392703
# 120470                0.713299             2.959901               -0.179113
# 376542                0.338502             2.979522                0.210060
# 349195                0.329165            -0.099940                3.041064
# 48316                -0.561104             2.419819               -0.204623
#
#         PRI_jet_num  PRI_jet_all_pt    PRI_met  PRI_met_phi  DER_mass_jet_jet  \
# 361401            2       184.57141   6.739553    -0.628886        301.174650
# 120470            2       217.01888  13.014414    -0.201907        274.141379
# 376542            3       258.29530  41.885810     0.220421        207.860439
# 349195            2       260.87335   2.849268     3.088427        275.904797
# 48316             3       294.22300   2.428770    -0.799237        265.372434
#
#         label  DER_mass_lep
# 361401      1     85.838600
# 120470      1     91.243780
# 376542      1     90.437010
# 349195      1     84.253174
# 48316       1     91.571910

# %%
# For the trials we make a smaller train and test sets:

train_small = train.sample(frac = 0.05, random_state = 5)
test_small = test.sample(frac = 0.05, random_state = 5)

X_train_small, X_test_small = train_small.drop(columns = ["label"]), test_small.drop(columns = ["label"])
y_train_small, y_test_small = train_small["label"], test_small["label"]

X_train_small = scaler.fit_transform(X_train_small)
X_test_small = scaler.transform(X_test_small)

# Check the sizes
print("Train size:", len(X_train_small))
print("Test size:", len(X_test_small))
# Out:
# Train size: 13854
# Test size: 8312

# %%
X_train_small.shape
# Out:
# (13854, 12)

# %%
# We define a function to create residual blocks (considering a layer regularizer L2)

def residual_block(x, n, activation, dropout, dropout_rate, regularizer, r_2):
        
    residual = x  
        
    if dropout == "y":
        # Main path
        x = layers.Dense(n, activation = activation, kernel_regularizer = regularizers.l2(r_2))(x)
        x = layers.BatchNormalization()(x)
        
        # Intermediate dropout layer
        x = layers.Dropout(dropout_rate)(x)
            
        # Linear layer
        x = layers.Dense(n, kernel_regularizer = regularizers.l2(r_2))(x)
        x = layers.BatchNormalization()(x)
            
    else: 
        # Main path
        x = layers.Dense(n, activation = activation, kernel_regularizer = regularizers.l2(r_2))(x)
        x = layers.BatchNormalization()(x)
            
        # Linear layer
        x = layers.Dense(n, kernel_regularizer = regularizers.l2(r_2))(x)
        x = layers.BatchNormalization()(x)

    # Project shortcut to same dimension
    residual = layers.Dense(n)(residual)

    # Conection residual sum
    x = layers.add([x, residual]) 
    x = layers.Activation(activation)(x)
        
    return x

# %%
# We create the function to start the study and optimizarion using Optuna
def objective(trial):

    tf.keras.backend.clear_session()

    inputs = layers.Input(shape = (X_train.shape[1],))
    
    #############################################################################################################
    
    # Optuna suggests activation function for all layers
    activation = trial.suggest_categorical("activation", ["relu", "relu6", "leaky_relu"])
    
    # Optuna suggests regularizer L2 value
    regularizer = "L2"
    r_2 = trial.suggest_float("regularizer_value_2", 1e-7, 1e-5, log = True)
    
    # Optuna suggest the number of layers
    n_layers = trial.suggest_int("N_layers", 15,20)
    
    # Optuna suggests learning rate value and an optimizer
    lr = trial.suggest_float("learning_rate", 2.5e-4, 1e-3, log = True)
    
    optimizer_name = trial.suggest_categorical("optimizer", ["sgd", "adam", "rmsprop", "adamw"])
                              
    if optimizer_name == "sgd":
        optimizer = tf.keras.optimizers.SGD(learning_rate = lr)
    elif optimizer_name == "adam":
        optimizer = tf.keras.optimizers.Adam(learning_rate = lr)
    elif optimizer_name == "rmsprop":
        optimizer = tf.keras.optimizers.RMSprop(learning_rate = lr)
    elif optimizer_name == "adamw":
        optimizer = tf.keras.optimizers.AdamW(learning_rate = lr)              
    
    #############################################################################################################
    
    # First layer

    # Optuna suggest number of neurons for the first layer

    N = trial.suggest_int("N_1st_layer", 128, 256)
    
    x = layers.Dense(N, input_shape = (X_train.shape[1],))(inputs)
    x = layers.Activation(activation)(x)
    x = layers.BatchNormalization()(x)
    
    # Optuna suggests neurons for the residual blocks and if using Dropout block
    
    dropout_per_layer = []
    dropout_percentage_per_layer = []
            
    dropping_out = trial.suggest_categorical("Dropout", ["y", "n"])

    N_per_layer = []
    
    for i in range(n_layers):
        
        n = trial.suggest_int(f"N_{i+1}_layer", 128, 256)
        N_per_layer.append(n)
                              
        dropout_rate = trial.suggest_float(f"Dropout_value_L{i+2}",0.1, 0.15)
        
        # i-th residual block:
        
        # Choosing between Dropout or a regulizer
        
        if dropping_out == "y":
            dropout_percentage_per_layer.append(dropout_rate)
            x = residual_block(x, n, activation, "y", dropout_rate, regularizer, r_2)

        else:
            dropout_percentage_per_layer.append(0.0)
            x = residual_block(x, n, activation, "n", dropout_rate, regularizer, r_2)            
            
    x = layers.Dropout(0.4)(x)  
    outputs = layers.Dense(1, activation = "sigmoid")(x)
    model = models.Model(inputs, outputs)
                              
    model.compile(optimizer = optimizer,
                  loss = "binary_crossentropy",
                  metrics = ["accuracy",
                             tf.keras.metrics.Precision(),
                             tf.keras.metrics.AUC(curve = "ROC"),
                             tf.keras.metrics.AUC(curve = "PR")])
    
    #############################################################################################################

    wandb.init(
        project = "Residual-SnB-Trials-3.0",
        name = f"Trial_{trial.number}",
        reinit = True,
        config = {
            "Units_1": N,
            "Units_per_layer": N_per_layer,
            "activation": activation,
            "n_layers": n_layers,
            "regularizer": regularizer,
            "r_value2": r_2,
            "Dropout": dropping_out, 
            "dropout_percentage_per_layer": dropout_percentage_per_layer,
            "learning_rate": lr,
            "optimizer": optimizer_name        }
    )
    
    #############################################################################################################
    
    """
    Callbacks
    """
    early_stopping = EarlyStopping(monitor = "val_accuracy", patience = 7, restore_best_weights = True)
    lr_reduction = ReduceLROnPlateau(monitor = "val_loss", factor = 0.1, patience = 5)
#     tensorboard_cb = TensorBoard(log_dir = "/workspace/Optuna-Trials/Plant-Pathology-Classificator/tf_debug", histogram_freq = 1, write_graph = True,
#                                  write_images = False)
    
    #############################################################################################################
    
    """
    Creación del modelo
    """
    
    try:
        print(model.summary())
    
        history = model.fit(
            X_train_small, y_train_small,
            validation_data = (X_test_small, y_test_small),
            batch_size = 32,
            epochs = 200,
            verbose = 1, 
            callbacks = [WandbMetricsLogger(log_freq = 5), early_stopping, lr_reduction]
        )

        val_loss = min(history.history["val_loss"])
        val_accuracy = max(history.history["val_accuracy"])
        
        train_loss = min(history.history["loss"])
        train_accuracy = max(history.history["accuracy"])
    
    except tf.errors.ResourceExhaustedError as e:
        
        print(f"Intento {trial.number} falló debido a: {e}")
        
        tf.keras.backend.clear_session()
        wandb.finish()
        gc.collect()
        
        return float("inf")

    except Exception as e:
        
        print(f"Intento {trial.number} falló. Unexpected error: {e}")
        
        tf.keras.backend.clear_session()
        wandb.finish()
        gc.collect()
        
        return float("inf")
    
    # score = val_loss + 0.1 * (train_loss - val_loss)
    
    score = val_accuracy
    
    # score = train_loss 
    
    tf.keras.backend.clear_session()
    gc.collect()
    wandb.finish()

    return 1-score

# %%
# study = optuna.create_study(
#     study_name = "Residual-Trials-2.0",
#     direction = "minimize",
#     storage = "sqlite:////workspace/Optuna-Trials/ResNet_SnB_study.db",
#     load_if_exists = True
# )

# study.optimize(objective, n_trials = 500)

# %%
activation = "leaky_relu"
units1 = 145
units_per_1ayer = [137,256,165,184,210,242,181,208,240,242,230,168,134,131,239,238]
r2 = 0.00000079738161723436
eta = 0.0003372509283896598

tf.keras.backend.clear_session()
inputs = layers.Input(shape = (X_train.shape[1],))
x = layers.Dense(units1, input_shape = (X_train.shape[1],))(inputs)
x = layers.Activation(activation)(x)
x = layers.BatchNormalization()(x)

for i in range(len(units_per_1ayer)):
    n = units_per_1ayer[i]
    x = residual_block(x, n, activation, "n", 0.0, "L2", r2)            
            
x = layers.Dropout(0.4)(x)  
outputs = layers.Dense(1, activation = "sigmoid")(x)
model = models.Model(inputs, outputs)

model.compile(optimizer = tf.keras.optimizers.RMSprop(learning_rate = eta),
              loss = "binary_crossentropy",
              metrics = ["accuracy",
                         tf.keras.metrics.Precision(),
                         tf.keras.metrics.AUC(curve = "ROC"),
                         tf.keras.metrics.AUC(curve = "PR")])

wandb.init(project = "Residual-SnB(AllData)-Trials-1.0",
           name = "Trial_1",
           reinit = True,
           config = {
               "Units_1": units1,
               "Units_per_layer": units_per_1ayer,
               "activation": activation,
               "n_layers": len(units_per_1ayer),
               "regularizer": "R2",
               "r_value2": r2,
               "learning_rate": eta,
               "optimizer": "RMSprop"})

print(model.summary())

early_stopping = EarlyStopping(monitor = "val_accuracy", patience = 7, restore_best_weights = True)
lr_reduction = ReduceLROnPlateau(monitor = "val_loss", factor = 0.1, patience = 5)

history = model.fit(X_train, y_train,
                    validation_data = (X_test, y_test),
                    batch_size = 32,
                    epochs = 200,
                    verbose = 1, 
                    callbacks = [WandbMetricsLogger(log_freq = 5), early_stopping, lr_reduction]
                   )

val_loss = min(history.history["val_loss"])
val_accuracy = max(history.history["val_accuracy"])
        
train_loss = min(history.history["loss"])
train_accuracy = max(history.history["accuracy"])

tf.keras.backend.clear_session()
gc.collect()
wandb.finish()
# Out:
# 2026-02-22 05:03:25.267114: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-02-22 05:03:25.270071: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-02-22 05:03:25.273181: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-02-22 05:03:25.408325: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-02-22 05:03:25.409226: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-02-22 05:03:25.410449: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-02-22 05:03:25.411209: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 698 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# Tracking run with wandb version 0.22.3
# Run data is saved locally in <code>/tf/Higgs-Boson-LHC-Collision-Detector/Trials-ANN/wandb/run-20260222_050326-lso38kuo</code>
# Syncing run <strong><a href='https://wandb.ai/emmdaz-zzz/Residual-SnB%28AllData%29-Trials-1.0/runs/lso38kuo' target="_blank">Trial_1</a></strong> to <a href='https://wandb.ai/emmdaz-zzz/Residual-SnB%28AllData%29-Trials-1.0' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/emmdaz-zzz/Residual-SnB%28AllData%29-Trials-1.0' target="_blank">https://wandb.ai/emmdaz-zzz/Residual-SnB%28AllData%29-Trials-1.0</a>
#  View run at <a href='https://wandb.ai/emmdaz-zzz/Residual-SnB%28AllData%29-Trials-1.0/runs/lso38kuo' target="_blank">https://wandb.ai/emmdaz-zzz/Residual-SnB%28AllData%29-Trials-1.0/runs/lso38kuo</a>
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 12)]                 0         []
#
#  dense (Dense)               (None, 145)                  1885      ['input_1[0][0]']
#
#  activation (Activation)     (None, 145)                  0         ['dense[0][0]']
#
#  batch_normalization (Batch  (None, 145)                  580       ['activation[0][0]']
#  Normalization)
#
#  dense_1 (Dense)             (None, 137)                  20002     ['batch_normalization[0][0]']
#
#  batch_normalization_1 (Bat  (None, 137)                  548       ['dense_1[0][0]']
#  chNormalization)
#
#  dense_2 (Dense)             (None, 137)                  18906     ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  batch_normalization_2 (Bat  (None, 137)                  548       ['dense_2[0][0]']
#  chNormalization)
#
#  dense_3 (Dense)             (None, 137)                  20002     ['batch_normalization[0][0]']
#
#  add (Add)                   (None, 137)                  0         ['batch_normalization_2[0][0]'
#                                                                     , 'dense_3[0][0]']
#
#  activation_1 (Activation)   (None, 137)                  0         ['add[0][0]']
#
#  dense_4 (Dense)             (None, 256)                  35328     ['activation_1[0][0]']
#
#  batch_normalization_3 (Bat  (None, 256)                  1024      ['dense_4[0][0]']
#  chNormalization)
#
#  dense_5 (Dense)             (None, 256)                  65792     ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  batch_normalization_4 (Bat  (None, 256)                  1024      ['dense_5[0][0]']
#  chNormalization)
#
#  dense_6 (Dense)             (None, 256)                  35328     ['activation_1[0][0]']
#
#  add_1 (Add)                 (None, 256)                  0         ['batch_normalization_4[0][0]'
#                                                                     , 'dense_6[0][0]']
#
#  activation_2 (Activation)   (None, 256)                  0         ['add_1[0][0]']
#
#  dense_7 (Dense)             (None, 165)                  42405     ['activation_2[0][0]']
#
#  batch_normalization_5 (Bat  (None, 165)                  660       ['dense_7[0][0]']
#  chNormalization)
#
#  dense_8 (Dense)             (None, 165)                  27390     ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  batch_normalization_6 (Bat  (None, 165)                  660       ['dense_8[0][0]']
#  chNormalization)
#
#  dense_9 (Dense)             (None, 165)                  42405     ['activation_2[0][0]']
#
#  add_2 (Add)                 (None, 165)                  0         ['batch_normalization_6[0][0]'
#                                                                     , 'dense_9[0][0]']
#
#  activation_3 (Activation)   (None, 165)                  0         ['add_2[0][0]']
#
#  dense_10 (Dense)            (None, 184)                  30544     ['activation_3[0][0]']
#
#  batch_normalization_7 (Bat  (None, 184)                  736       ['dense_10[0][0]']
#  chNormalization)
#
#  dense_11 (Dense)            (None, 184)                  34040     ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  batch_normalization_8 (Bat  (None, 184)                  736       ['dense_11[0][0]']
#  chNormalization)
#
#  dense_12 (Dense)            (None, 184)                  30544     ['activation_3[0][0]']
#
#  add_3 (Add)                 (None, 184)                  0         ['batch_normalization_8[0][0]'
#                                                                     , 'dense_12[0][0]']
#
#  activation_4 (Activation)   (None, 184)                  0         ['add_3[0][0]']
#
#  dense_13 (Dense)            (None, 210)                  38850     ['activation_4[0][0]']
#
#  batch_normalization_9 (Bat  (None, 210)                  840       ['dense_13[0][0]']
#  chNormalization)
#
#  dense_14 (Dense)            (None, 210)                  44310     ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  batch_normalization_10 (Ba  (None, 210)                  840       ['dense_14[0][0]']
#  tchNormalization)
#
#  dense_15 (Dense)            (None, 210)                  38850     ['activation_4[0][0]']
#
#  add_4 (Add)                 (None, 210)                  0         ['batch_normalization_10[0][0]
#                                                                     ',
#                                                                      'dense_15[0][0]']
#
#  activation_5 (Activation)   (None, 210)                  0         ['add_4[0][0]']
#
#  dense_16 (Dense)            (None, 242)                  51062     ['activation_5[0][0]']
#
#  batch_normalization_11 (Ba  (None, 242)                  968       ['dense_16[0][0]']
#  tchNormalization)
#
#  dense_17 (Dense)            (None, 242)                  58806     ['batch_normalization_11[0][0]
#                                                                     ']
#
#  batch_normalization_12 (Ba  (None, 242)                  968       ['dense_17[0][0]']
#  tchNormalization)
#
#  dense_18 (Dense)            (None, 242)                  51062     ['activation_5[0][0]']
#
#  add_5 (Add)                 (None, 242)                  0         ['batch_normalization_12[0][0]
#                                                                     ',
#                                                                      'dense_18[0][0]']
#
#  activation_6 (Activation)   (None, 242)                  0         ['add_5[0][0]']
#
#  dense_19 (Dense)            (None, 181)                  43983     ['activation_6[0][0]']
#
#  batch_normalization_13 (Ba  (None, 181)                  724       ['dense_19[0][0]']
#  tchNormalization)
#
#  dense_20 (Dense)            (None, 181)                  32942     ['batch_normalization_13[0][0]
#                                                                     ']
#
#  batch_normalization_14 (Ba  (None, 181)                  724       ['dense_20[0][0]']
#  tchNormalization)
#
#  dense_21 (Dense)            (None, 181)                  43983     ['activation_6[0][0]']
#
#  add_6 (Add)                 (None, 181)                  0         ['batch_normalization_14[0][0]
#                                                                     ',
#                                                                      'dense_21[0][0]']
#
#  activation_7 (Activation)   (None, 181)                  0         ['add_6[0][0]']
#
#  dense_22 (Dense)            (None, 208)                  37856     ['activation_7[0][0]']
#
#  batch_normalization_15 (Ba  (None, 208)                  832       ['dense_22[0][0]']
#  tchNormalization)
#
#  dense_23 (Dense)            (None, 208)                  43472     ['batch_normalization_15[0][0]
#                                                                     ']
#
#  batch_normalization_16 (Ba  (None, 208)                  832       ['dense_23[0][0]']
#  tchNormalization)
#
#  dense_24 (Dense)            (None, 208)                  37856     ['activation_7[0][0]']
#
#  add_7 (Add)                 (None, 208)                  0         ['batch_normalization_16[0][0]
#                                                                     ',
#                                                                      'dense_24[0][0]']
#
#  activation_8 (Activation)   (None, 208)                  0         ['add_7[0][0]']
#
#  dense_25 (Dense)            (None, 240)                  50160     ['activation_8[0][0]']
#
#  batch_normalization_17 (Ba  (None, 240)                  960       ['dense_25[0][0]']
#  tchNormalization)
#
#  dense_26 (Dense)            (None, 240)                  57840     ['batch_normalization_17[0][0]
#                                                                     ']
#
#  batch_normalization_18 (Ba  (None, 240)                  960       ['dense_26[0][0]']
#  tchNormalization)
#
#  dense_27 (Dense)            (None, 240)                  50160     ['activation_8[0][0]']
#
#  add_8 (Add)                 (None, 240)                  0         ['batch_normalization_18[0][0]
#                                                                     ',
#                                                                      'dense_27[0][0]']
#
#  activation_9 (Activation)   (None, 240)                  0         ['add_8[0][0]']
#
#  dense_28 (Dense)            (None, 242)                  58322     ['activation_9[0][0]']
#
#  batch_normalization_19 (Ba  (None, 242)                  968       ['dense_28[0][0]']
#  tchNormalization)
#
#  dense_29 (Dense)            (None, 242)                  58806     ['batch_normalization_19[0][0]
#                                                                     ']
#
#  batch_normalization_20 (Ba  (None, 242)                  968       ['dense_29[0][0]']
#  tchNormalization)
#
#  dense_30 (Dense)            (None, 242)                  58322     ['activation_9[0][0]']
#
#  add_9 (Add)                 (None, 242)                  0         ['batch_normalization_20[0][0]
#                                                                     ',
#                                                                      'dense_30[0][0]']
#
#  activation_10 (Activation)  (None, 242)                  0         ['add_9[0][0]']
#
#  dense_31 (Dense)            (None, 230)                  55890     ['activation_10[0][0]']
#
#  batch_normalization_21 (Ba  (None, 230)                  920       ['dense_31[0][0]']
#  tchNormalization)
#
#  dense_32 (Dense)            (None, 230)                  53130     ['batch_normalization_21[0][0]
#                                                                     ']
#
#  batch_normalization_22 (Ba  (None, 230)                  920       ['dense_32[0][0]']
#  tchNormalization)
#
#  dense_33 (Dense)            (None, 230)                  55890     ['activation_10[0][0]']
#
#  add_10 (Add)                (None, 230)                  0         ['batch_normalization_22[0][0]
#                                                                     ',
#                                                                      'dense_33[0][0]']
#
#  activation_11 (Activation)  (None, 230)                  0         ['add_10[0][0]']
#
#  dense_34 (Dense)            (None, 168)                  38808     ['activation_11[0][0]']
#
#  batch_normalization_23 (Ba  (None, 168)                  672       ['dense_34[0][0]']
#  tchNormalization)
#
#  dense_35 (Dense)            (None, 168)                  28392     ['batch_normalization_23[0][0]
#                                                                     ']
#
#  batch_normalization_24 (Ba  (None, 168)                  672       ['dense_35[0][0]']
#  tchNormalization)
#
#  dense_36 (Dense)            (None, 168)                  38808     ['activation_11[0][0]']
#
#  add_11 (Add)                (None, 168)                  0         ['batch_normalization_24[0][0]
#                                                                     ',
#                                                                      'dense_36[0][0]']
#
#  activation_12 (Activation)  (None, 168)                  0         ['add_11[0][0]']
#
#  dense_37 (Dense)            (None, 134)                  22646     ['activation_12[0][0]']
#
#  batch_normalization_25 (Ba  (None, 134)                  536       ['dense_37[0][0]']
#  tchNormalization)
#
#  dense_38 (Dense)            (None, 134)                  18090     ['batch_normalization_25[0][0]
#                                                                     ']
#
#  batch_normalization_26 (Ba  (None, 134)                  536       ['dense_38[0][0]']
#  tchNormalization)
#
#  dense_39 (Dense)            (None, 134)                  22646     ['activation_12[0][0]']
#
#  add_12 (Add)                (None, 134)                  0         ['batch_normalization_26[0][0]
#                                                                     ',
#                                                                      'dense_39[0][0]']
#
#  activation_13 (Activation)  (None, 134)                  0         ['add_12[0][0]']
#
#  dense_40 (Dense)            (None, 131)                  17685     ['activation_13[0][0]']
#
#  batch_normalization_27 (Ba  (None, 131)                  524       ['dense_40[0][0]']
#  tchNormalization)
#
#  dense_41 (Dense)            (None, 131)                  17292     ['batch_normalization_27[0][0]
#                                                                     ']
#
#  batch_normalization_28 (Ba  (None, 131)                  524       ['dense_41[0][0]']
#  tchNormalization)
#
#  dense_42 (Dense)            (None, 131)                  17685     ['activation_13[0][0]']
#
#  add_13 (Add)                (None, 131)                  0         ['batch_normalization_28[0][0]
#                                                                     ',
#                                                                      'dense_42[0][0]']
#
#  activation_14 (Activation)  (None, 131)                  0         ['add_13[0][0]']
#
#  dense_43 (Dense)            (None, 239)                  31548     ['activation_14[0][0]']
#
#  batch_normalization_29 (Ba  (None, 239)                  956       ['dense_43[0][0]']
#  tchNormalization)
#
#  dense_44 (Dense)            (None, 239)                  57360     ['batch_normalization_29[0][0]
#                                                                     ']
#
#  batch_normalization_30 (Ba  (None, 239)                  956       ['dense_44[0][0]']
#  tchNormalization)
#
#  dense_45 (Dense)            (None, 239)                  31548     ['activation_14[0][0]']
#
#  add_14 (Add)                (None, 239)                  0         ['batch_normalization_30[0][0]
#                                                                     ',
#                                                                      'dense_45[0][0]']
#
#  activation_15 (Activation)  (None, 239)                  0         ['add_14[0][0]']
#
#  dense_46 (Dense)            (None, 238)                  57120     ['activation_15[0][0]']
#
#  batch_normalization_31 (Ba  (None, 238)                  952       ['dense_46[0][0]']
#  tchNormalization)
#
#  dense_47 (Dense)            (None, 238)                  56882     ['batch_normalization_31[0][0]
#                                                                     ']
#
#  batch_normalization_32 (Ba  (None, 238)                  952       ['dense_47[0][0]']
#  tchNormalization)
#
#  dense_48 (Dense)            (None, 238)                  57120     ['activation_15[0][0]']
#
#  add_15 (Add)                (None, 238)                  0         ['batch_normalization_32[0][0]
#                                                                     ',
#                                                                      'dense_48[0][0]']
#
#  activation_16 (Activation)  (None, 238)                  0         ['add_15[0][0]']
#
#  dropout (Dropout)           (None, 238)                  0         ['activation_16[0][0]']
#
#  dense_49 (Dense)            (None, 1)                    239       ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 1966212 (7.50 MB)
# Trainable params: 1953102 (7.45 MB)
# Non-trainable params: 13110 (51.21 KB)
# __________________________________________________________________________________________________
# None
# Epoch 1/200
# 2026-02-22 05:04:05.642810: I external/local_xla/xla/service/service.cc:168] XLA service 0x7e8f7005c660 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2026-02-22 05:04:05.642848: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce GTX 1650, Compute Capability 7.5
# 2026-02-22 05:04:05.664593: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2026-02-22 05:04:05.708234: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8906
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1771736645.744172   27401 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 8659/8659 [==============================] - 230s 25ms/step - loss: 0.0373 - accuracy: 0.9908 - precision: 0.9945 - auc: 0.9981 - auc_1: 0.9991 - val_loss: 0.0192 - val_accuracy: 0.9980 - val_precision: 0.9992 - val_auc: 0.9994 - val_auc_1: 0.9997 - lr: 3.3725e-04
# Epoch 2/200
# 8659/8659 [==============================] - 213s 25ms/step - loss: 0.0178 - accuracy: 0.9975 - precision: 0.9986 - auc: 0.9992 - auc_1: 0.9996 - val_loss: 0.0180 - val_accuracy: 0.9973 - val_precision: 0.9970 - val_auc: 0.9992 - val_auc_1: 0.9995 - lr: 3.3725e-04
# Epoch 3/200
# 8659/8659 [==============================] - 213s 25ms/step - loss: 0.0173 - accuracy: 0.9979 - precision: 0.9989 - auc: 0.9992 - auc_1: 0.9996 - val_loss: 0.0202 - val_accuracy: 0.9985 - val_precision: 0.9986 - val_auc: 0.9992 - val_auc_1: 0.9995 - lr: 3.3725e-04
# Epoch 4/200
# 8659/8659 [==============================] - 213s 25ms/step - loss: 0.0183 - accuracy: 0.9978 - precision: 0.9987 - auc: 0.9992 - auc_1: 0.9996 - val_loss: 0.0169 - val_accuracy: 0.9990 - val_precision: 0.9995 - val_auc: 0.9997 - val_auc_1: 0.9998 - lr: 3.3725e-04
# Epoch 5/200
# 8659/8659 [==============================] - 214s 25ms/step - loss: 0.0180 - accuracy: 0.9980 - precision: 0.9989 - auc: 0.9992 - auc_1: 0.9996 - val_loss: 0.0166 - val_accuracy: 0.9992 - val_precision: 0.9995 - val_auc: 0.9994 - val_auc_1: 0.9996 - lr: 3.3725e-04
# Epoch 6/200
# 8659/8659 [==============================] - 214s 25ms/step - loss: 0.0192 - accuracy: 0.9979 - precision: 0.9988 - auc: 0.9993 - auc_1: 0.9996 - val_loss: 0.0132 - val_accuracy: 0.9989 - val_precision: 0.9989 - val_auc: 0.9995 - val_auc_1: 0.9997 - lr: 3.3725e-04
# Epoch 7/200
# 8659/8659 [==============================] - 214s 25ms/step - loss: 0.0865 - accuracy: 0.9977 - precision: 0.9989 - auc: 0.9988 - auc_1: 0.9994 - val_loss: 0.0613 - val_accuracy: 0.9965 - val_precision: 0.9957 - val_auc: 0.9957 - val_auc_1: 0.9971 - lr: 3.3725e-04
# Epoch 8/200
# 8659/8659 [==============================] - 215s 25ms/step - loss: 0.7607 - accuracy: 0.9979 - precision: 0.9988 - auc: 0.9991 - auc_1: 0.9995 - val_loss: 0.0314 - val_accuracy: 0.9989 - val_precision: 0.9996 - val_auc: 0.9992 - val_auc_1: 0.9996 - lr: 3.3725e-04
# Epoch 9/200
# 8659/8659 [==============================] - 215s 25ms/step - loss: 0.0692 - accuracy: 0.9979 - precision: 0.9989 - auc: 0.9991 - auc_1: 0.9995 - val_loss: 0.0452 - val_accuracy: 0.9987 - val_precision: 0.9987 - val_auc: 0.9990 - val_auc_1: 0.9993 - lr: 3.3725e-04
# Epoch 10/200
# 8659/8659 [==============================] - 215s 25ms/step - loss: 0.0671 - accuracy: 0.9978 - precision: 0.9987 - auc: 0.9990 - auc_1: 0.9994 - val_loss: 0.5009 - val_accuracy: 0.9985 - val_precision: 0.9992 - val_auc: 0.9988 - val_auc_1: 0.9994 - lr: 3.3725e-04
# Epoch 11/200
# 8659/8659 [==============================] - 215s 25ms/step - loss: 0.0375 - accuracy: 0.9981 - precision: 0.9989 - auc: 0.9992 - auc_1: 0.9996 - val_loss: 0.0181 - val_accuracy: 0.9989 - val_precision: 0.9989 - val_auc: 0.9992 - val_auc_1: 0.9995 - lr: 3.3725e-04
# Epoch 12/200
# 8659/8659 [==============================] - 215s 25ms/step - loss: 0.0087 - accuracy: 0.9992 - precision: 0.9996 - auc: 0.9997 - auc_1: 0.9998 - val_loss: 0.0102 - val_accuracy: 0.9993 - val_precision: 0.9994 - val_auc: 0.9996 - val_auc_1: 0.9998 - lr: 3.3725e-05
# Epoch 13/200
# 8659/8659 [==============================] - 215s 25ms/step - loss: 0.0082 - accuracy: 0.9993 - precision: 0.9996 - auc: 0.9998 - auc_1: 0.9999 - val_loss: 0.0106 - val_accuracy: 0.9994 - val_precision: 0.9995 - val_auc: 0.9997 - val_auc_1: 0.9998 - lr: 3.3725e-05
# Epoch 14/200
# 8659/8659 [==============================] - 215s 25ms/step - loss: 0.0086 - accuracy: 0.9993 - precision: 0.9997 - auc: 0.9997 - auc_1: 0.9999 - val_loss: 0.0115 - val_accuracy: 0.9994 - val_precision: 0.9996 - val_auc: 0.9996 - val_auc_1: 0.9998 - lr: 3.3725e-05
# Epoch 15/200
# 8659/8659 [==============================] - 216s 25ms/step - loss: 0.0085 - accuracy: 0.9993 - precision: 0.9996 - auc: 0.9997 - auc_1: 0.9999 - val_loss: 0.0147 - val_accuracy: 0.9994 - val_precision: 0.9994 - val_auc: 0.9995 - val_auc_1: 0.9997 - lr: 3.3725e-05
# Epoch 16/200
# 8659/8659 [==============================] - 216s 25ms/step - loss: 0.0086 - accuracy: 0.9993 - precision: 0.9997 - auc: 0.9998 - auc_1: 0.9999 - val_loss: 0.0205 - val_accuracy: 0.9994 - val_precision: 0.9995 - val_auc: 0.9995 - val_auc_1: 0.9997 - lr: 3.3725e-05
# Epoch 17/200
# 8659/8659 [==============================] - 216s 25ms/step - loss: 0.0088 - accuracy: 0.9993 - precision: 0.9997 - auc: 0.9997 - auc_1: 0.9999 - val_loss: 0.0207 - val_accuracy: 0.9994 - val_precision: 0.9995 - val_auc: 0.9995 - val_auc_1: 0.9997 - lr: 3.3725e-05
# Epoch 18/200
# 8659/8659 [==============================] - 216s 25ms/step - loss: 0.0083 - accuracy: 0.9994 - precision: 0.9997 - auc: 0.9997 - auc_1: 0.9999 - val_loss: 0.0180 - val_accuracy: 0.9995 - val_precision: 0.9996 - val_auc: 0.9996 - val_auc_1: 0.9998 - lr: 3.3725e-06
# Epoch 19/200
# 8659/8659 [==============================] - 216s 25ms/step - loss: 0.0080 - accuracy: 0.9994 - precision: 0.9997 - auc: 0.9997 - auc_1: 0.9999 - val_loss: 0.0177 - val_accuracy: 0.9994 - val_precision: 0.9995 - val_auc: 0.9996 - val_auc_1: 0.9998 - lr: 3.3725e-06
# Epoch 20/200
# 8659/8659 [==============================] - 216s 25ms/step - loss: 0.0079 - accuracy: 0.9994 - precision: 0.9997 - auc: 0.9998 - auc_1: 0.9999 - val_loss: 0.0188 - val_accuracy: 0.9994 - val_precision: 0.9995 - val_auc: 0.9997 - val_auc_1: 0.9998 - lr: 3.3725e-06
# Epoch 21/200
# 8659/8659 [==============================] - 216s 25ms/step - loss: 0.0076 - accuracy: 0.9994 - precision: 0.9997 - auc: 0.9998 - auc_1: 0.9999 - val_loss: 0.0205 - val_accuracy: 0.9994 - val_precision: 0.9995 - val_auc: 0.9996 - val_auc_1: 0.9997 - lr: 3.3725e-06
# Epoch 22/200
# 8659/8659 [==============================] - 216s 25ms/step - loss: 0.0080 - accuracy: 0.9993 - precision: 0.9997 - auc: 0.9997 - auc_1: 0.9999 - val_loss: 0.0191 - val_accuracy: 0.9995 - val_precision: 0.9996 - val_auc: 0.9996 - val_auc_1: 0.9998 - lr: 3.3725e-06
# Epoch 23/200
# 8659/8659 [==============================] - 216s 25ms/step - loss: 0.0076 - accuracy: 0.9994 - precision: 0.9997 - auc: 0.9998 - auc_1: 0.9999 - val_loss: 0.0210 - val_accuracy: 0.9994 - val_precision: 0.9995 - val_auc: 0.9997 - val_auc_1: 0.9998 - lr: 3.3725e-07
# Epoch 24/200
# 8659/8659 [==============================] - 216s 25ms/step - loss: 0.0077 - accuracy: 0.9995 - precision: 0.9998 - auc: 0.9998 - auc_1: 0.9999 - val_loss: 0.0217 - val_accuracy: 0.9994 - val_precision: 0.9995 - val_auc: 0.9996 - val_auc_1: 0.9998 - lr: 3.3725e-07
# Epoch 25/200
# 8659/8659 [==============================] - 216s 25ms/step - loss: 0.0079 - accuracy: 0.9993 - precision: 0.9997 - auc: 0.9997 - auc_1: 0.9999 - val_loss: 0.0193 - val_accuracy: 0.9995 - val_precision: 0.9995 - val_auc: 0.9996 - val_auc_1: 0.9998 - lr: 3.3725e-07
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>batch/accuracy</td><td>▁▇██████████████████████████████████████</td></tr><tr><td>batch/auc</td><td>▁▅▆▆▆▆▆▆▆▆▆▆▆▆▆▇▆▇▆██▇██▇██▇▇▇██▇▇▇█████</td></tr><tr><td>batch/auc_1</td><td>▁▆▇▇▇▇▇▇█▇▇▇▇▇▇▇▇▇▇█████████████████████</td></tr><tr><td>batch/batch_step</td><td>▁▁▁▂▂▂▂▂▂▂▃▃▃▃▄▄▅▅▅▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇████</td></tr><tr><td>batch/learning_rate</td><td>███████████████████▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>batch/loss</td><td>▂▂▁▁▁▁▁▁▁▁▁▁▁▂▂▁▂▂▂█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>batch/precision</td><td>▁▁▃▃▂▃▃▂▃▄▃▃▃▃▃▆▄▃▇▆▇█▇▇▇▇▆▇▇▇▇▆▇▇▇▇▆▇▇▇</td></tr><tr><td>epoch/accuracy</td><td>▁▆▇▇▇▇▇▇▇▇▇██████████████</td></tr><tr><td>epoch/auc</td><td>▁▅▅▅▅▆▄▅▅▄▆██████████████</td></tr><tr><td>epoch/auc_1</td><td>▁▅▅▅▅▆▃▅▅▄▅██████████████</td></tr><tr><td>+9</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>batch/accuracy</td><td>0.99933</td></tr><tr><td>batch/auc</td><td>0.99975</td></tr><tr><td>batch/auc_1</td><td>0.99988</td></tr><tr><td>batch/batch_step</td><td>216495</td></tr><tr><td>batch/learning_rate</td><td>0.0</td></tr><tr><td>batch/loss</td><td>0.00789</td></tr><tr><td>batch/precision</td><td>0.99967</td></tr><tr><td>epoch/accuracy</td><td>0.99933</td></tr><tr><td>epoch/auc</td><td>0.99975</td></tr><tr><td>epoch/auc_1</td><td>0.99988</td></tr><tr><td>+9</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Trial_1</strong> at: <a href='https://wandb.ai/emmdaz-zzz/Residual-SnB%28AllData%29-Trials-1.0/runs/lso38kuo' target="_blank">https://wandb.ai/emmdaz-zzz/Residual-SnB%28AllData%29-Trials-1.0/runs/lso38kuo</a><br> View project at: <a href='https://wandb.ai/emmdaz-zzz/Residual-SnB%28AllData%29-Trials-1.0' target="_blank">https://wandb.ai/emmdaz-zzz/Residual-SnB%28AllData%29-Trials-1.0</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260222_050326-lso38kuo/logs</code>

# %%
model.save("ResNet-SnB-Classificator.keras")

# %%
model_ev = keras.models.load_model("ResNet-SnB-Classificator.keras")

loss, accuracy, precision, auc, auc_1 = model_ev.evaluate(X_val, y_val, verbose = 1)

print(f"Test Loss: {loss:}")
print(f"Test Accuracy: {accuracy:}")
# Out:
# 3464/3464 [==============================] - 17s 5ms/step - loss: 0.0171 - accuracy: 0.9995 - precision: 0.9997 - auc: 0.9997 - auc_1: 0.9998
# Test Loss: 0.01707211323082447
# Test Accuracy: 0.999512791633606

# %%
from sklearn.metrics import confusion_matrix

y_pred = model_ev.predict(X_val)
y_pred_classes = (y_pred > 0.5).astype("int32")

cm = confusion_matrix(y_pred_classes, y_val)
sns.heatmap(cm, annot = True, fmt = "d", cmap = "rocket")

plt.xlabel("Prediction")
plt.ylabel("Real Value")
plt.show()
# Out:
# 3464/3464 [==============================] - 12s 3ms/step
